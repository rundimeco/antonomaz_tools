# %% [markdown]
# # Search_pdf_on_GALLICA_from_a_list
# * En entrée : liste de titres de documents à rechercher sur Gallica
# * En sortie : un fichier avec la liste de tous les titres trouvés et leurs url + un fichier avec la même liste et un comparateur de similarité pour confronter les résultats avec les titres requêtés.

# %%
#Import des librairies nécessaires
import os
import re
import urllib
import lxml.etree as etree
import glob
import jellyfish

# %% [markdown]
# ## Lancer l'API GALLICA et pré-filtrer les résultats
# * Format de fichier en entrée : .txt ou .tsv
#
# * une ligne = identification_du_document (tabulation) titre_à_chercher

# %%
def load_clean_tronc(path, erase_ponctuation = True, nb_mots = 10):
#Pour charger les titres à requêter, supprimer la ponctuation et les couper car les titres longs 
#sont plus susceptibles de générer de mauvais résultats dans l'api.
#Path = chemin vers le fichier où sont les titres
#nb_mots = nombre de mots à garder pour les titres-requêtes
#erase_ponctuation = True pour supprimer la ponctuation"""
    with open(path, "r", encoding='utf8') as f :
        lignes=f.readlines()
    if erase_ponctuation == True :
        lignes_clean = [re.sub(" \([\w]+[\'|\’]?\)", "", i) for i in lignes]
        lignes_clean = [re.sub('[^\w\t ]+', ' ', i) for i in lignes_clean]
        lignes_clean = [re.sub('  ', ' ', i) for i in lignes_clean]
        lignes_clean = [re.sub("\n", '', i) for i in lignes_clean]
    else :
        lignes_clean=lignes
    liste_tronquee=[]
    for l in lignes_clean:
        try:
            idMoreau, titre=re.split("\t",l)
        except:
            print("erreur à la ligne suivante : "+l)
        if len(titre)<40:
            liste_tronquee.append(idMoreau+"\t"+titre)
        if len(titre)>40:
            try:
                titre_coupe=re.split(" ",titre)
            except:
                print("erreur dans le titre suivant : "+titre)
            titre_tronque=titre_coupe[0:nb_mots]
            titre_tronque_str = '%20'.join(titre_tronque)
            liste_tronquee.append(idMoreau+"\t"+titre_tronque_str)
    return liste_tronquee

# %%
def launch_api_gallica(path, max_results = 40):
#Cette fonction transforme les titres en requête URL valide dans l'api gallica, puis enregistre les résultats de
#l'api dans un fichier XML (identifiant_du_titre.xml) 
#paramètres API gallica : cherche toutes les monographies contenant les mots du titre, publiées au XVIIe siècle
    liste_tronquee = load_clean_tronc(path, erase_ponctuation = True, nb_mots = 10)
    try:
        os.mkdir('sortie_xml')
    except:
        pass
    chaine1 = "https://gallica.bnf.fr/SRU?operation=searchRetrieve&version=1.2&query=%20gallica%20any%20%22"
    chaine2 = "%22%20and%20dc.type%20any%20monographie%20and%20(century%20adj%20%2217%22)&maximumRecords="
    chaine3 = "%s" %max_results
    list_no_results=[]
    for l in liste_tronquee:
        idMoreau, titre=re.split("\t",l)
        titre_ascii=urllib.parse.quote(titre) #transformer les titres au format ascii
        url= chaine1 + titre_ascii + chaine2 + chaine3
        try:
            txt = urllib.request.urlretrieve(url, 'sortie_xml/%s.xml' %idMoreau)
        except:
            list_no_results.append(l)
    if not(list_no_results):
        print("Tous les titres ont été requêtés et les résultats enregistrés dans des XML.")
    else:
        #relancer l'api sur les titres qui n'ont pas pu être requêtés avec une autre clé GBOOKS:
        print("Nombre de titres pour lesquels la recherche API n'a pas fonctionné : "+str(len(list_no_results))+". Liste des titres enregistrée au format .txt au même niveau que ce script.")

# %%
def download_filtered_url(nombre = 40, regex="1648|1649|1650|1651|1652|1653|1654"):
#enregistre dans une liste les résultats de l'api correspondants à la recherche avec : 
#date de publi + titre du document + adresse URL où télécharger le doc
#Enregistre les résultats au format .txt
#nombre = nombre max de résultats de la requête de l'api selectionné
#regex = mettre la date ou les dates de publication qui serviront à filtrer les résultats
    p = re.compile("%s" %regex,re.IGNORECASE)
    liste_url=[]
    for filepath in glob.iglob('sortie_xml/*.xml'):
            if filepath.endswith('.xml'):
                tree = etree.parse("%s" %filepath)
                for i in range(nombre): 
                    for date in tree.xpath("/srw:searchRetrieveResponse/srw:records[1]/srw:record[%s]/srw:recordData[1]/oai_dc:dc[1]/dc:date[1]" %str(i+1),
                              namespaces={'srw': 'http://www.loc.gov/zing/srw/','oai_dc':"http://www.openarchives.org/OAI/2.0/oai_dc/",'dc':'http://purl.org/dc/elements/1.1/'}):
                        m = p.search(date.text)
                        if m:
                            v_date=m.group()
                            for title in tree.xpath("/srw:searchRetrieveResponse/srw:records[1]/srw:record[%s]/srw:recordData[1]/oai_dc:dc[1]/dc:title[1]" %str(i+1),
                                       namespaces={'srw': 'http://www.loc.gov/zing/srw/','oai_dc':"http://www.openarchives.org/OAI/2.0/oai_dc/",'dc':'http://purl.org/dc/elements/1.1/'}):
                                v_titre=title.text
                            for link in tree.xpath("/srw:searchRetrieveResponse/srw:records[1]/srw:record[%s]/srw:extraRecordData[1]/link[1]" %str(i+1),
                                      namespaces={'srw': 'http://www.loc.gov/zing/srw/'}):
                                v_url=link.text
                            ligne=str(v_date)+"\t"+v_titre+"\t"+v_url
                            liste_url.append(ligne)
    liste_url=list(set(liste_url))
    print("Nombre de fichiers correspondants trouvés : " + str(len(liste_url)))
    try:
        os.mkdir('output')
    except:
        pass
    open("output/liste_url.txt", "w", encoding="utf8")
    for l in liste_url :
        with open ("output/liste_url.txt", "a", encoding="utf8") as f:
            f.write(l+"\n"+"\n")
    return liste_url

# %% [markdown]
# ## Passer le résultat de l'API dans le get_similar_titles

# %%
def get_tsv(path):
    f = open(path,encoding="utf-8")
    liste = f.readlines()
    f.close()
    return liste

def get_closest(path,title, number = 5):
#En entrée, une chaîne de caractère (et en option le nombre de titres proches à retourner, par défaut : 5)
#En sortie, la liste triée par ordre décroissant de similarité sous forme d'un triplet:
#distance, ID_moreau, titre concerné.
    liste = get_tsv(path)
    mots_titre = set(title.split())
    filtered_list = []
    for l in  liste:
        ID, chaine=re.split("\t",l)
        mots_candidat = set(chaine.split())
        inter = mots_titre.intersection(mots_candidat)
        ##Si moins de 5 mots en commun (ou de la moitié) inutile de garder le candidat
        if len(inter)>5 or len(inter)>(len(mots_titre)/2):
            filtered_list.append([len(inter), ID, chaine])
    f2 = []
    for len_inter, ID, chaine in filtered_list:
        sim = jellyfish.jaro_winkler(title,chaine)
        ## On garde quand la similarité est supérieure à 0.5
        if sim>0.5:
            f2.append([sim, ID, chaine])
    return sorted(f2, reverse=True)[:number]

# %%
def download_results(path,nombre = 40, regex="1648|1649|1650|1651|1652|1653|1654"):
#nombre = nombre de sortie api gallica à intégrer dans les résultats enregistrés pour une requête
#enregistrer les résultats dans un fichier .txt à ouvrir avec notepad++ pour plus de lisibilité
#regex=mettre une ou des dates de publication (séparées par des "|") pour filtrer les résultats
    liste_titres = download_filtered_url(nombre, regex)
    dic= {}
    cpt = 0
    open ("output/output_similar.txt", "w", encoding="utf8")
    for lt in liste_titres: #A titre d'exemple
        date, titre,url=re.split("\t",lt)
        with open ("output/output_similar.txt", "a", encoding="utf8") as f:
            f.write("\n"+"-"*30+"\n"+ date + "\t"+ titre + "\n"+ url+"\n")
        print("-"*30)
        print(date, titre, url)
        closest_titles = get_closest(path,titre)
        for dist, ID_moreau, chaine in closest_titles:
            result=f"  D={round(dist, 4)} (ID={ID_moreau}): {chaine[:70]}"
            print(result)
            with open ("output/output_similar.txt", "a", encoding="utf8") as f:
                f.write (result+"\n")

# %% [markdown]
# # Exemple d'utilisation :
# * Remplacer "essai_titre.txt" par le nom de votre fichier avec les titres à chercher en respectant le format (id_titre+tabulation+titre+saut de ligne). Veiller à ce qu'il se trouve bien au même niveau que ce script.
# * Cliquer sur Cell > Run all. Attendre quelques minutes.
# * L'ensemble des résultats de l'application se trouvent dans le dossier de sortie "output", créé au même niveau que le script.
# * Conseil : ouvrir le fichier "output_similar.txt" avec le logiciel notepad++ pour une meilleure lisibilité.

# %%
launch_api_gallica("CoulonTitres.txt",max_results = 40)
# Out:
# Nombre de titres pour lesquels la recherche API n'a pas fonctionné : 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ab6d49b8acd4> in <module>
# ----> 1 launch_api_gallica("CoulonTitres.txt",max_results = 40)
#
# <ipython-input-11-3c228c006f7c> in launch_api_gallica(path, max_results)
#      24     else:
#      25         #relancer l'api sur les titres qui n'ont pas pu être requêtés avec une autre clé GBOOKS:
# ---> 26         print("Nombre de titres pour lesquels la recherche API n'a pas fonctionné : "+str(len(list_no_results)))+". Liste des titres enregistrée au format .txt au même niveau que ce script."
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
download_results("CoulonTitres.txt", nombre = 40, regex="1648|1649|1650|1651|1652|1653|1654")
# Out:
# Nombre de fichiers correspondants trouvés : 315
# ------------------------------
# 1648 Le Virgile travesty en vers burlesques , de M. Scarron. Dédié à la Reyne https://gallica.bnf.fr/ark:/12148/bpt6k123053b
#   D=0.567 (ID=106): Recit du duel memorable fait à Ruel entre dix laquais des deputez, & a
# ------------------------------
# 1651 Réflexions sur l'arest du Parlement donné en faveur de Mr le Duc de Vendosme contre les prétensions de Mr le Duc d'Elboeuf https://gallica.bnf.fr/ark:/12148/bpt6k5425495x
# ------------------------------
# 1649 Avis+ heroïques et importants donnez à Mr le prince de Condé # par monsieur de Chastillon, revenu de l'autre monde . Par l'autheur mesme des Triolets [du prince de Condé] https://gallica.bnf.fr/ark:/12148/bpt6k5661053j
# ------------------------------
# 1653 Ismaelis Bullialdi observatio secundi deliquii lunaris anno 1652 mense septembri facti, una cum calculo illius, et futuri alius lunae defectus mense martio 1653 ex tabulis Philolaicis, et Observationes circa cometam qui mense decembri 1652 fulsit, tam ab ipso quam ab aliis factae https://gallica.bnf.fr/ark:/12148/btv1b86262635
# ------------------------------
# 1649 Procez verbaux des deux conferences : la premiere, tenuë à Ruel le dernier jour de fevrier, & autres jours suivans, entre les deputez du Roy, & les deputez du Parlement, & des autres compagnies souveraines. La seconde, tenuë à S. Germain en Laye, le 16. jour de mars, & autres suivans, 1649. entre les deputez du Roy, & ceux du Parlement, & des compagnies souveraines de la ville de Roüen. https://gallica.bnf.fr/ark:/12148/bpt6k9736281b
#   D=0.7329 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.
(ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
# ------------------------------
# 1652 Articles de l'union de l'Ormée en la ville de Bordeaux. https://gallica.bnf.fr/ark:/12148/bpt6k317923c
# ------------------------------
# 1649 Devises héroïques et morales, du P. Pierre Le Moine ["sic"],... https://gallica.bnf.fr/ark:/12148/bpt6k1522506r
# ------------------------------
# 1654 Clélie, histoire romaine : dédiée à Mademoiselle de Longueville. vol. 3, t.1 / par Mr de Scudery,... https://gallica.bnf.fr/ark:/12148/bpt6k108433s
# ------------------------------
# 1649 Récit véritable de ce qui s'est passé aux barricades de l'année mil cinq cens quatre vingts huict depuis le septiesme May jusques au dernier Juin en suivant . Descrites en vers burlesque https://gallica.bnf.fr/ark:/12148/bpt6k10485771
#   D=0.7413 (ID=117): Lettre déchiffrée contenant plusieurs avis qu'un des émissaires et esp
#   D=0.724 (ID=96): Lettre déchiffrée, contenant plusieurs advis qu’un des émissaires et e
#   D=0.7158 (ID=98): Lettre contenant ce qui s’est passé en l’Assemblée du Parlement, depui
#   D=0.7116 (ID=115): Lettre contenant ce qui s'est passé en l'assemblée du Parlement, depui
# ------------------------------
# 1652 Le caractère de la royauté et de la tyrannie, faisant voir par un discours politique https://gallica.bnf.fr/ark:/12148/bpt6k800834
# ------------------------------
# 1652 Les presens faits à Son A. royalle et à Messieurs les Princes de Condé et de Beaufort à leur arrivée au Palais. Pour Messieurs du Parlement https://gallica.bnf.fr/ark:/12148/bpt6k57085353
#   D=0.6704 (ID=125): Requête (la) des bourgeois de Paris à nosseigneurs du Parlement toucha
# ------------------------------
# 1649 Hircanus tragoedia dabitur in Theatrum Regiae Navarrae ad solennem praemiorum distributionem ex munificentia Ludovici XIIII regis christianissimi die lunae 30. Augusti M.DC.XLIX. post meridiem https://gallica.bnf.fr/ark:/12148/bpt6k1523873h
# ------------------------------
# 1652 Relation derniere et veritable de tout ce qui s'est passé en l'attaque & combat de la ville d'Estampes entre l'Armée du Roy & celle de Mrs. les Princes, vers S. Lazare & le lieu appellé les Corps Saints, depuis le 29. mai jusques au 1. juin 1652. https://gallica.bnf.fr/ark:/12148/bpt6k8588198
#   D=0.7993 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
#   D=0.776 (ID=106): Recit du duel memorable fait à Ruel entre dix laquais des deputez, & a
#   D=0.7688 (ID=124): Récit du duel mémorable fait à Ruel entre dix laquais des députés et a
#   D=0.728 (ID=117): Lettre déchiffrée contenant plusieurs avis qu'un des émissaires et esp
#   D=0.7096 (ID=120): Manifeste pour M. le duc de Bouillon et messieurs les autres généraux
# ------------------------------
# 1649 Agreable recit de ce qui s'est passé aux dernieres barricades de Paris. Descrites en vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k1048579v
# ------------------------------
# 1649 Diverses pieces de ce qui s'est passé a S. Germain en Laye, le vingt-troisiéme janvier 1649. et suivans. https://gallica.bnf.fr/ark:/12148/bpt6k328835p
#   D=0.6617 (ID=115): Lettre contenant ce qui s'est passé en l'assemblée du Parlement, depui
#   D=0.6161 (ID=117): Lettre déchiffrée contenant plusieurs avis qu'un des émissaires et esp
#   D=0.6065 (ID=96): Lettre déchiffrée, contenant plusieurs advis qu’un des émissaires et e
#   D=0.5758 (ID=133): État (l’) de la marche et le lieu où est à présent l’armée de l’archid
#   D=0.5553 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
# ------------------------------
# 1652 Les Oeuvres... 3e édition https://gallica.bnf.fr/ark:/12148/bpt6k8720860w
# ------------------------------
# 1652 Nouveau caquet ou entretien de l'accouchée, sur le départ du cardinal Mazarin de la ville de Dinan, jusques à son arrivée à Sedan. Première journée https://gallica.bnf.fr/ark:/12148/bpt6k8584110
#   D=0.6834 (ID=143): France (la) réjouie par le génie du roi pour la conservation de son ro
#   D=0.6597 (ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
#   D=0.5941 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
(ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
#   D=0.6874 (ID=133): État (l’) de la marche et le lieu où est à présent l’armée de l’archid
#   D=0.6496 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.648 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.6315 (ID=135): Flambeau (le) d'Olympe, dédié à monseigneur le ; duc de Beaufort, avec
# ------------------------------
# 1652 Relation contenant le secours jetté dans la Ville de Gravelines, par les soins du Sieur d'Estrades Lieutenant General dans les Armées du Roy & Gouverneur de Dunkerque : avec l'estat de cette premiere place, & ce qui s'est passé en son siege. jusques au 29. de ce Mois. https://gallica.bnf.fr/ark:/12148/bpt6k852189v
#   D=0.7967 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
#   D=0.7347 (ID=117): Lettre déchiffrée contenant plusieurs avis qu'un des émissaires et esp
#   D=0.713 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
#   D=0.7122 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.7094 (ID=120): Manifeste pour M. le duc de Bouillon et messieurs les autres généraux
# ------------------------------
# 1649 Antinocier+ ou le Blasme des :nopces: +noces+ de monsieur de Mercoeur avec la :niepce: +nièce+ de Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k56574345
# ------------------------------
# 1652 Le tableau de la croix representé dans les ceremonies de la S.te messe ensemble le tresor de la devotion aux soufrances de N.re S. I. C. le tout enrichi de belles figures https://gallica.bnf.fr/ark:/12148/bpt6k1511180b
#   D=0.6724 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.6681 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
# ------------------------------
# 1650 La France conservée par le génie du Roy... [Signé : Laisné.] https://gallica.bnf.fr/ark:/12148/bpt6k58466370
#   D=0.8863 (ID=147): La France conservée par le génie du roy, présentée ‘ à Sa Majesté
#
# ------------------------------
# 1652 La declaration de Monseigneur le Duc de Beaufort, envoyée à Messieurs de Parlement. https://gallica.bnf.fr/ark:/12148/bpt6k850176t
# ------------------------------
# 1652 Relation véritable de l'horrible assassinat commis par les fripiers de la nation judaïque, en la personne d'un bourgeois de cette ville de Paris, le 26 août 1652 https://gallica.bnf.fr/ark:/12148/bpt6k840458k
#   D=0.7624 (ID=144): Revers (le) du prince de Condé, en vers bur lesques , et le regret de
#   D=0.7149 (ID=161): Harangue faite au Roy a son arrivee dans la ville de Melun par le lieu
#   D=0.7003 (ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
#   D=0.6924 (ID=134): Extrait d’une lettre envoyée de Ruel, en date du vendredi 19° de ce mo
#   D=0.6716 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
# ------------------------------
# 1653 Soliman ou l'Esclave généreuse, tragédie [par Jacquelin] https://gallica.bnf.fr/ark:/12148/bpt6k8528590
# ------------------------------
# 1650 Edict du Roy portant creation & augmentation d'officiers en la cour des monnoyes : et le reglement de leur pouvoir & juridiction https://gallica.bnf.fr/ark:/12148/bpt6k1188952x
#   D=0.6609 (ID=158): Les Délibérations prises et arrêtées en l’Hôtel de Ville pour la levée
#   D=0.6362 (ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
#   D=0.6318 (ID=144): Revers (le) du prince de Condé, en vers bur lesques , et le regret de
#   D=0.6208 (ID=124): Récit du duel mémorable fait à Ruel entre dix laquais des députés et a
#   D=0.6131 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
# ------------------------------
# 1650 Le Cid, tragi-comédie https://gallica.bnf.fr/ark:/12148/bpt6k1280247z
#   D=0.5794 (ID=62): Le Cid, Paris, Veuve Jean Camusat et Pierre Le Petit, 1644, in-4°.
#
# ------------------------------
# 1654 Les oeuvres diverses / de Mr de Cyrano Bergerac https://gallica.bnf.fr/ark:/12148/bpt6k71169w
# ------------------------------
# 1649 Le nocturne enlevement du Roy hors de Paris, fait par le cardinal Mazarin la nuict des Roys. En vers burlesques. https://gallica.bnf.fr/ark:/12148/bpt6k1048495m
#   D=0.6849 (ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
#   D=0.6809 (ID=159): La fureur des Juifs, dediee a messieurs de la Synagogue. En vers burle
#   D=0.6731 (ID=108): Recit du duel memorable fait à Ruel entre dix laquais des deputez, & a
#   D=0.6582 (ID=144): Revers (le) du prince de Condé, en vers bur lesques , et le regret de
#   D=0
(ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
#   D=0.6864 (ID=133): État (l’) de la marche et le lieu où est à présent l’armée de l’archid
#   D=0.6545 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.6358 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.6267 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
# ------------------------------
# 1651 Édits, déclaration, arrests et règlemens pour les offices de jaugeurs https://gallica.bnf.fr/ark:/12148/bpt6k1454917
# ------------------------------
# 1650 Le Paranymphe aromatique, dédié à Monseigneur le Duc de Beaufort https://gallica.bnf.fr/ark:/12148/bpt6k5612444w
# ------------------------------
# 1649 Divine revelation arrivée à un bon religieux, Du retour du Roy, & de la Paix. https://gallica.bnf.fr/ark:/12148/bpt6k857024z
# ------------------------------
# ...
#   D=0.6816 (ID=120): Manifeste pour M. le duc de Bouillon et messieurs les autres généraux
#   D=0.6801 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.663 (ID=113): Décadence (la) des mauvais ministres d’État, et les fruits qu'ils ont
#   D=0.6549 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.6338 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
# ------------------------------
# 1650 La Comédie des académistes pour la réformation de la langue françoise , pièce comique avec le roole des présentations, faites aux grands jours de ladite Académie https://gallica.bnf.fr/ark:/12148/bpt6k1524645t
#   D=0.6544 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.6461 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
# ------------------------------
# 1649 La nouvelle Paris, ou l'heureux changement de ses maux par le retour de son Roy https://gallica.bnf.fr/ark:/12148/bpt6k56103245
#   D=0.6111 (ID=105): La metamorphose morale ou l'heureux changement de nos fortunes. Par la
# ------------------------------
# 1650 Affectionnés+ souhaits du peuple de Paris, pour la conservation :&: +et+ progrés de leurs :Majestez: +Majestés+ dans leurs voyages, & leur marche en Bourgongne https://gallica.bnf.fr/ark:/12148/bpt6k55750332
#   D=0.6563 (ID=144): Revers (le) du prince de Condé, en vers bur lesques , et le regret de
#   D=0.6072 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.6057 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
# ------------------------------
# 1652 Philosophia moralis christiana https://gallica.bnf.fr/ark:/12148/bpt6k95614c
# ------------------------------
# 1652 Histoire véritable d'une colombe qui a paru miraculeusement en un lieu appelé l'Ormaye de Bordeaux, proche la ville, le 15 avril 1652, sur les 7 heures du matin, en présence de tous les bourgeois qui étaient là assemblés pour prévoir à leur conservation dans ces troubles https://gallica.bnf.fr/ark:/12148/bpt6k317945t
#   D=0.7434 (ID=120): Manifeste pour M. le duc de Bouillon et messieurs les autres généraux
#   D=0.7189 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.7144 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
#   D=0.7014 (ID=133): État (l’) de la marche et le lieu où est à présent l’armée de l’archid
#   D=0.6952 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
# ------------------------------
# 1649 Replique au suffisant, et captieux censeur de la lettre d'avis presentée au Parlement par un provincial. https://gallica.bnf.fr/ark:/12148/bpt6k841028k
# ------------------------------
# 1651 Scipion ou Le parfait Romain . Dedié a Son Altesse Monseigneur le duc de Longuevile. Par Monsieur de La Serre, conseiller du Roy en ses conseils d'Estat, & historiographe de France. https://gallica.bnf.fr/ark:/12148/bpt6k1510212j
#   D=0.6934 (ID=120): Manifeste pour M. le duc de Bouillon et messieurs les autres généraux
#   D=0.6787 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.6231 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
# ------------------------------
# 1648 L'Homme chrestien, ou la Réparation de la nature par la grâce, par le R.P. Jean-François Senault,... https://gallica.bnf.fr/ark:/12148/bpt6k8707890n
# ------------------------------
# 1654 Le Jodelet, ou Le maître valet , comédie https://gallica.bnf.fr/ark:/12148/bpt6k73913z
# ------------------------------
# 1649 Le Flambeau d'Olympe, dédié à Monseigneur le duc de Beaufort... par le sr Barroys https://gallica.bnf.fr/ark:/12148/bpt6k5576494f
#   D=0.6898 (ID=135): Flambeau (le) d'Olympe, dédié à monseigneur le ; duc de Beaufort, avec
# ------------------------------
(ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.7716 (ID=115): Lettre contenant ce qui s'est passé en l'assemblée du Parlement, depui
#   D=0.7635 (ID=98): Lettre contenant ce qui s’est passé en l’Assemblée du Parlement, depui
# ------------------------------
# 1648 Le Jodelet, ou Le M. valet , comédie de Mr de Scarron https://gallica.bnf.fr/ark:/12148/bpt6k724480
# ------------------------------
# 1649 La curieuse et plaisante guerre des plaideurs en vogue. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5707774k
# ------------------------------
# 1651 Tulipanthomanie, ou l'envelope de la pierre lunaire de Moreau, le philosophe, renvoyée en très-grande diligence de Rouen à Paris, par le Sieur de Tourne-Mer, au chevalier de Saint-Marc, pour la faire tenir par la poste. Aux bons, grands, riches marchands floristes de Lyon et de Toulouse pour l'intelligence de ce noble trafic https://gallica.bnf.fr/ark:/12148/bpt6k5544194z
#   D=0.7386 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.7121 (ID=120): Manifeste pour M. le duc de Bouillon et messieurs les autres généraux
#   D=0.7093 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.7007 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
#   D=0.6516 (ID=144): Revers (le) du prince de Condé, en vers bur lesques , et le regret de
# ------------------------------
# 1649 Le parlement de Bourgogne, son origine, son établissement et son progrès , avec les noms, sur-noms, qualités, armes et blasons, des présidents, chevaliers, conseillers, avocats et procureurs généraux, et greffiers, qui y ont été jusques à présent, par Pierre Palliot,... https://gallica.bnf.fr/ark:/12148/bpt6k94759c
#   D=0.7646 (ID=117): Lettre déchiffrée contenant plusieurs avis qu'un des émissaires et esp
#   D=0.6863 (ID=128): Royauté (la) de Charles second , roi de la Grand’ Bretagne, etc., reco
#   D=0.6821 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.6812 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
#   D=0.6776 (ID=133): État (l’) de la marche et le lieu où est à présent l’armée de l’archid
# ------------------------------
# 1649 Le Cid, tragi-comédie par le Sr. Corneille https://gallica.bnf.fr/ark:/12148/bpt6k1280246j
# ------------------------------
# 1649 Le pour et contre de la Cour. https://gallica.bnf.fr/ark:/12148/bpt6k5545346w
#   D=0.5923 (ID=131): Discours de la Clémence et de la Justice au parlement, pour et contre
#   D=0.5752 (ID=158): Les Délibérations prises et arrêtées en l’Hôtel de Ville pour la levée
#   D=0.5694 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.5689 (ID=144): Revers (le) du prince de Condé, en vers bur lesques , et le regret de
#   D=0.5666 (ID=95): Le Revers du mauvais temps passé et la libre entrée de ma paix…, Paris
# ------------------------------
# 1648 Thémistocle : tragédie / de P. Du Ryer https://gallica.bnf.fr/ark:/12148/bpt6k715768
# ------------------------------
# 1649 Très-humble remonstrance du Parlement au Roy et à la Reyne Regente (21 janv. 1649, signé Du Tillet) / (attribué au président Le Coigneux) https://gallica.bnf.fr/ark:/12148/bpt6k1006069
# ------------------------------
# 1649 Cosroes. Tragedie. De monsieur de Rotrou. https://gallica.bnf.fr/ark:/12148/bpt6k70801z
# ------------------------------
# 1649 La vision prophétique de sainte Geneviève, patrone et protectrice de la ville de Paris https://gallica.bnf.fr/ark:/12148/bpt6k857019h
# ------------------------------
# 1654 Prédiction merveilleuse du sieur Andreas, astrologue & mathématicien de Padoue, sur l'éclipse de soleil qui se fera le douziesme jour d'aout 1654 . Avec son explication et l'approbation d'Eistadius, grand astrologue https://gallica.bnf.fr/ark:/12148/bpt6k851793h
#   D=0.6605 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
# ------------------------------
# 1648 Typhon, ou La gigantomachie . Poëme burlesque. Dedie a monseigneur l'eminentissime cardinal Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k72451w
# ------------------------------
# 1654 Relation de ce qui s'est passé en la mission des Pères de la Compagnie de Jésus, au pays de la Nouvelle France, depuis l'été de l'année 1652 jusques à l'été de l'année 1653 . Envoyée au R. P. provincial de la province de France.Par le supérieur des missions de la mesme Compagnie. [Signé : François Le Mercier.] https://gallica.bnf.fr/ark:/12148/bpt6k131865m
#   D=0.7738 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
#   D=0.7254 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.7064 (ID=117): Lettre déchiffrée contenant plusieurs avis qu'un des émissaires et esp
#   D=0.6708 (ID=96): Lettre déchiffrée, contenant plusieurs advis qu’un des émissaires et e
#   D=0.6621 (ID=115): Lettre contenant ce qui s'est passé en l'assemblée du Parlement, depui
# ------------------------------
# 1650 Pharmacopée de Bauderon . Reveue, corrigee et augmentée de plusieurs compositions necessaires : & des facultez de chaque composition. Avec un Traicté des plus usitez & celebres medicamens chymiques. Par G. Sauvageon. D. M. aggregé au College des medecins de Lion https://gallica.bnf.fr/ark:/12148/bpt6k1511546p
# ------------------------------
# 1648 Summae virtutum ac vitiorum.... Tome 2 https://gallica.bnf.fr/ark:/12148/bpt6k57658865
# ------------------------------
# 1651 Le Cid, tragédie https://gallica.bnf.fr/ark:/12148/bpt6k1280315b
#   D=0.5919 (ID=62): Le Cid, Paris, Veuve Jean Camusat et Pierre Le Petit, 1644, in-4°.
#
# ------------------------------
# 1649 L'effroyable accouchement d'un monstre dans Paris, et ce qui s'est ensuivi après sa naissance https://gallica.bnf.fr/ark:/12148/bpt6k131965x
# ------------------------------
# 1648 Cinna ou la Clémence d'Auguste https://gallica.bnf.fr/ark:/12148/bpt6k12802951
# ------------------------------
# 1654 La Philosophie divisée en toutes ses parties, établie sur des principes évidents et expliquée en tables et par discours... par Jaques Du Roure. - La Philosophie de Jaques Du Roure. Tome II, contenant la physique. - La Philosophie de Jaques Du Roure. Tome III, contenant la morale des écoles et la morale démontrée https://gallica.bnf.fr/ark:/12148/bpt6k134023t
#   D=0.7307 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.5988 (ID=146): Progrès (les) des armes du roi sur les frontières de la Lorraine, et l
# ------------------------------
# 1648 Le Livre de S. Augustin, de la foy, de l'espérance et de la charité . Adressé à Laurent, chef du Collège des notaires & secretaires de la ville de Rome. Pour luy servir de manuel, & d'un abrégé de la doctrine du christianisme. Traduit en françois par M. Antoine Arnault,... avec le latin en suite, reveu exactement sur six anciens manuscripts https://gallica.bnf.fr/ark:/12148/bpt6k97347534
#   D=0.7945 (ID=136): Lettre de M. d'Auremesnil, chef de la noblesse de Caux en Normandie, e
#   D=0.7921 (ID=160): Les particularitez du second combat donné entre l'armée de son Altesse
#   D=0.7622 (ID=154): La harangue du roy de la Grand Bretagne a la reyne de France, faicte a
#   D=0.7258 (ID=106): Recit du duel memorable fait à Ruel entre dix laquais des deputez, & a
#   D=0.7211 (ID=162): Recit veritable de tout ce qui s'est passé à l'Hostel de Ville touchan
# ------------------------------
# 1649 Visions astrologiques de Michel Nostradamus sur toutes les affaires de ce temps, et la confusion de Mazarin . En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k118539m
#   D=0.6727 (ID=118): Lettre du sieur de Nacar à l'abbé de La Rivière, à Saint-Germain-en-La

# %% [markdown]
# **L'ensemble des résultats de l'application se trouvent dans le dossier de sortie "output".**
