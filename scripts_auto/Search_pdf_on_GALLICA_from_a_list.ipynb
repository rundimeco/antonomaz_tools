# %% [markdown]
# # Search_pdf_on_GALLICA_from_a_list
# * En entrée : liste de titres de documents à rechercher sur Gallica
# * En sortie : un fichier avec la liste de tous les titres trouvés et leurs url + un fichier avec la même liste et un comparateur de similarité pour confronter les résultats avec les titres requêtés.

# %%
#Import des librairies nécessaires
import os
import re
import urllib
import lxml.etree as etree
import glob
import jellyfish

# %% [markdown]
# ## Lancer l'API GALLICA et pré-filtrer les résultats
# * Format de fichier en entrée : .txt ou .tsv
#
# * une ligne = identification_du_document (tabulation) titre_à_chercher

# %%
def load_clean_tronc(path, erase_ponctuation = True, nb_mots = 10):
#Pour charger les titres à requêter, supprimer la ponctuation et les couper car les titres longs 
#sont plus susceptibles de générer de mauvais résultats dans l'api.
#Path = chemin vers le fichier où sont les titres
#nb_mots = nombre de mots à garder pour les titres-requêtes
#erase_ponctuation = True pour supprimer la ponctuation"""
    with open(path, "r", encoding='utf8') as f :
        lignes=f.readlines()
    if erase_ponctuation == True :
        lignes_clean = [re.sub(" \([\w]+[\'|\’]?\)", "", i) for i in lignes]
        lignes_clean = [re.sub('[^\w\t ]+', ' ', i) for i in lignes_clean]
        lignes_clean = [re.sub('  ', ' ', i) for i in lignes_clean]
        lignes_clean = [re.sub("\n", '', i) for i in lignes_clean]
    else :
        lignes_clean=lignes
    liste_tronquee=[]
    for l in lignes_clean:
        try:
            idMoreau, titre=re.split("\t",l)
        except:
            print("erreur à la ligne suivante : "+l)
        if len(titre)<40:
            liste_tronquee.append(idMoreau+"\t"+titre)
        if len(titre)>40:
            try:
                titre_coupe=re.split(" ",titre)
            except:
                print("erreur dans le titre suivant : "+titre)
            titre_tronque=titre_coupe[0:nb_mots]
            titre_tronque_str = '%20'.join(titre_tronque)
            liste_tronquee.append(idMoreau+"\t"+titre_tronque_str)
    return liste_tronquee

# %%
def launch_api_gallica(path, max_results = 40):
#Cette fonction transforme les titres en requête URL valide dans l'api gallica, puis enregistre les résultats de
#l'api dans un fichier XML (identifiant_du_titre.xml) 
#paramètres API gallica : cherche toutes les monographies contenant les mots du titre, publiées au XVIIe siècle
    liste_tronquee = load_clean_tronc(path, erase_ponctuation = True, nb_mots = 10)
    try:
        os.mkdir('sortie_xml')
    except:
        pass
    chaine1 = "https://gallica.bnf.fr/SRU?operation=searchRetrieve&version=1.2&query=%20gallica%20any%20%22"
    chaine2 = "%22%20and%20dc.type%20any%20monographie%20and%20(century%20adj%20%2217%22)&maximumRecords="
    chaine3 = "%s" %max_results
    list_no_results=[]
    for l in liste_tronquee:
        idMoreau, titre=re.split("\t",l)
        titre_ascii=urllib.parse.quote(titre) #transformer les titres au format ascii
        url= chaine1 + titre_ascii + chaine2 + chaine3
        try:
            txt = urllib.request.urlretrieve(url, 'sortie_xml/%s.xml' %idMoreau)
        except:
            list_no_results.append(l)
    if not(list_no_results):
        print("Tous les titres ont été requêtés et les résultats enregistrés dans des XML.")
    else:
        #relancer l'api sur les titres qui n'ont pas pu être requêtés avec une autre clé GBOOKS:
        print("Nombre de titres pour lesquels la recherche API n'a pas fonctionné : "+str(len(list_no_results))+". Liste des titres enregistrée au format .txt au même niveau que ce script.")

# %%
def download_filtered_url(nombre = 40, regex="1648|1649|1650|1651|1652|1653|1654"):
#enregistre dans une liste les résultats de l'api correspondants à la recherche avec : 
#date de publi + titre du document + adresse URL où télécharger le doc
#Enregistre les résultats au format .txt
#nombre = nombre max de résultats de la requête de l'api selectionné
#regex = mettre la date ou les dates de publication qui serviront à filtrer les résultats
    p = re.compile("%s" %regex,re.IGNORECASE)
    liste_url=[]
    for filepath in glob.iglob('sortie_xml/*.xml'):
            if filepath.endswith('.xml'):
                tree = etree.parse("%s" %filepath)
                for i in range(nombre): 
                    for date in tree.xpath("/srw:searchRetrieveResponse/srw:records[1]/srw:record[%s]/srw:recordData[1]/oai_dc:dc[1]/dc:date[1]" %str(i+1),
                              namespaces={'srw': 'http://www.loc.gov/zing/srw/','oai_dc':"http://www.openarchives.org/OAI/2.0/oai_dc/",'dc':'http://purl.org/dc/elements/1.1/'}):
                        m = p.search(date.text)
                        if m:
                            v_date=m.group()
                            for title in tree.xpath("/srw:searchRetrieveResponse/srw:records[1]/srw:record[%s]/srw:recordData[1]/oai_dc:dc[1]/dc:title[1]" %str(i+1),
                                       namespaces={'srw': 'http://www.loc.gov/zing/srw/','oai_dc':"http://www.openarchives.org/OAI/2.0/oai_dc/",'dc':'http://purl.org/dc/elements/1.1/'}):
                                v_titre=title.text
                            for link in tree.xpath("/srw:searchRetrieveResponse/srw:records[1]/srw:record[%s]/srw:extraRecordData[1]/link[1]" %str(i+1),
                                      namespaces={'srw': 'http://www.loc.gov/zing/srw/'}):
                                v_url=link.text
                            ligne=str(v_date)+"\t"+v_titre+"\t"+v_url
                            liste_url.append(ligne)
    liste_url=list(set(liste_url))
    print("Nombre de documents correspondants aux dates : " + str(len(liste_url)))
    try:
        os.mkdir('output')
    except:
        pass
    open("output/liste_url.txt", "w", encoding="utf8")
    for l in liste_url :
        with open ("output/liste_url.txt", "a", encoding="utf8") as f:
            f.write(l+"\n"+"\n")
    return liste_url

# %% [markdown]
# ## Passer le résultat de l'API dans le get_similar_titles

# %%
def get_tsv(path):
    f = open(path,encoding="utf-8")
    liste = f.readlines()
    f.close()
    return liste

def get_closest(path,title, number = 5):
#En entrée, une chaîne de caractère (et en option le nombre de titres proches à retourner, par défaut : 5)
#En sortie, la liste triée par ordre décroissant de similarité sous forme d'un triplet:
#distance, ID_moreau, titre concerné.
    liste = get_tsv(path)
    mots_titre = set(title.split())
    filtered_list = []
    for l in  liste:
        ID, chaine=re.split("\t",l)
        mots_candidat = set(chaine.split())
        inter = mots_titre.intersection(mots_candidat)
        ##Si moins de 5 mots en commun (ou de la moitié) inutile de garder le candidat
        if len(inter)>5 or len(inter)>(len(mots_titre)/2):
            filtered_list.append([len(inter), ID, chaine])
    f2 = []
    for len_inter, ID, chaine in filtered_list:
        sim = jellyfish.jaro_winkler(title,chaine)
        ## On garde quand la similarité est supérieure à 0.5
        if sim>0.5:
            f2.append([sim, ID, chaine])
    return sorted(f2, reverse=True)[:number]

# %%
def download_results(path,nombre = 40, regex="1648|1649|1650|1651|1652|1653|1654"):
#nombre = nombre de sortie api gallica à intégrer dans les résultats enregistrés pour une requête
#enregistrer les résultats dans un fichier .txt à ouvrir avec notepad++ pour plus de lisibilité
#regex=mettre une ou des dates de publication (séparées par des "|") pour filtrer les résultats
    liste_titres = download_filtered_url(nombre, regex)
    dic= {}
    cpt = 0
    open ("output/output_similar.txt", "w", encoding="utf8")
    for lt in liste_titres: #A titre d'exemple
        date, titre,url=re.split("\t",lt)
        with open ("output/output_similar.txt", "a", encoding="utf8") as f:
            f.write("\n"+"-"*30+"\n"+ date + "\t"+ titre + "\n"+ url+"\n")
        print("-"*30)
        print(date, titre, url)
        closest_titles = get_closest(path,titre)
        for dist, ID_moreau, chaine in closest_titles:
            result=f"  D={round(dist, 4)} (ID={ID_moreau}): {chaine[:70]}"
            print(result)
            with open ("output/output_similar.txt", "a", encoding="utf8") as f:
                f.write (result+"\n")

# %% [markdown]
# # Exemple d'utilisation :
# * Remplacer "essai_titre.txt" par le nom de votre fichier avec les titres à chercher en respectant le format (id_titre+tabulation+titre+saut de ligne). Veiller à ce qu'il se trouve bien au même niveau que ce script.
# * Cliquer sur Cell > Run all. Attendre quelques minutes.
# * L'ensemble des résultats de l'application se trouvent dans le dossier de sortie "output", créé au même niveau que le script.
# * Conseil : ouvrir le fichier "output_similar.txt" avec le logiciel notepad++ pour une meilleure lisibilité.

# %%
launch_api_gallica("Liste_Titres.txt",max_results = 40)
# Out:
# Tous les titres ont été requêtés et les résultats enregistrés dans des XML.

# %%
download_results("Liste_Titres.txt", nombre = 40, regex="1648|1649|1650|1651|1652|1653|1654")
# Out:
# Nombre de fichiers correspondants trouvés : 120
# ------------------------------
# 1649 L'Agatonphile de la France https://gallica.bnf.fr/ark:/12148/bpt6k55771405
# ------------------------------
# 1652 Triolets sur la jonction des princes, pour la deroute des Mazarins https://gallica.bnf.fr/ark:/12148/bpt6k54293789
# ------------------------------
# 1649 Divine revelation arrivée à un bon religieux, Du retour du Roy, & de la Paix. https://gallica.bnf.fr/ark:/12148/bpt6k857024z
# ------------------------------
# 1652 Inventaire des pièces que met et baille par devers vous, nos seigneurs de parlement, la Sagesse éternelle... est demanderesse, en restitution de la monarchie française... https://gallica.bnf.fr/ark:/12148/btv1b8606955g
# ------------------------------
# 1650 Dialogue des amours d'un sergent avec une villageoise https://gallica.bnf.fr/ark:/12148/bpt6k53993713
# ------------------------------
# 1648 Mémoires pour l'histoire de Navarre et de Flandre, contenant le droit du roi au royaume de Navarre et aux duchés de Pegnafiel, etc., etc. ; avec l'histoire de 150 années des guerres d'entre la France et la Flandre, depuis l'an 1180 jusques en 1331, qui justifient le droit de la couronne de France sur les villes et châtellenies de Lille, etc., avec les preuves authentiques : le tout dressé sur les titres et mémoires du cabinet de feu messire Auguste Galland, conseiller du roi, etc. https://gallica.bnf.fr/ark:/12148/bpt6k8717344z
#   D=0.5945 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Ballade à Jules Mazarin sur son jeu du Hoc https://gallica.bnf.fr/ark:/12148/bpt6k5707693k
# ------------------------------
# 1649 Antinocier+ ou le Blasme des :nopces: +noces+ de monsieur de Mercoeur avec la :niepce: +nièce+ de Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k56574345
#   D=0.6315 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1651 La Hierusalem céleste, l'assomption de la théologie de Dieu, le lion de la tribu de Juda, et l'inventaire de la vérité https://gallica.bnf.fr/ark:/12148/btv1b86069542
# ------------------------------
# 1651 Plaintes de la France à ses peuples sur l'emprisonnement des Princes contre Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k5725183d
# ------------------------------
# 1649 Declaration du Roy, portant attribution de juger souverainement, & en dernier ressort de toutes causes, tant civilles que criminelles, à tous les presidiaux du ressort du parlement de Paris. Et lesquelles ont esté leuës, publiées, & registrées, le jeudy vingt-huictiéme janvier [1649], l'audiance se tenant à Lyon. https://gallica.bnf.fr/ark:/12148/bpt6k97403101
# ------------------------------
# 1652 La declaration de Monseigneur le Duc de Beaufort, envoyée à Messieurs de Parlement. https://gallica.bnf.fr/ark:/12148/bpt6k850176t
# ------------------------------
# 1654 Le monde sousterrein, ou Description historique et philosophique de tous les plus beaux antres et de toutes les plus belles grottes de la terre... / par le Sr C. de Gaffarel https://gallica.bnf.fr/ark:/12148/bpt6k75426d
#   D=0.6928 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1650 L'Odyssée d'Homère, ou Les avantures d'Ulysse en vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k123061x
# ------------------------------
# 1652 Les veritez absolues et sans contredit. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5426094f
# ------------------------------
# 1649 L'on du temps tout nouveau, en vers burlesques par C. D. B. M. https://gallica.bnf.fr/ark:/12148/bpt6k5620095g
# ------------------------------
# 1649 La Fuitte des maltôtiers après Mazarin, mise en vers burlesques par le sieur Pomphollis https://gallica.bnf.fr/ark:/12148/bpt6k5723584k
# ------------------------------
# 1648 Journal de tout ce qui s'est fait en la cour et Parlement de Paris https://gallica.bnf.fr/ark:/12148/bpt6k94414k
# ------------------------------
# 1649 Le caquet des marchandes poissonnières et harengères des Halles, sur la maladie du duc de Beaufort, soupçonné de poison : et leur voyage au palais de ce prince https://gallica.bnf.fr/ark:/12148/bpt6k74900v
#   D=0.706 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 A Son Excellence Octave Picolomini d'Arragon, duc d'Amalfi, comte du Saint Empire, chevalier de la Toison d'or , conseiller intime d'Estat et de guerre de S. M. imperiale, lieutenant general de ses armées et premier plenipotentiaire pour l'execution de la paix d'Allemagne, &c https://gallica.bnf.fr/ark:/12148/bpt6k5400497n
# ------------------------------
# 1653 Extrait des registres de Parlement https://gallica.bnf.fr/ark:/12148/btv1b8620834n
# ------------------------------
# 1649 Traité de l'esprit de l'homme et de ses fonctions / par le sieur Chanet https://gallica.bnf.fr/ark:/12148/bpt6k76032g
# ------------------------------
# 1654 Le sacre et couronnement de Louis XIV... dans l'église de Reims, le septième juin 1654, où toutes les cérémonies, stances des cardinaux, prélats, officiers de la couronne et autres, avec leurs fonctions, sont fidèlement décrites, par l'ordre du chapitre de l'église métropolitaine de Reims https://gallica.bnf.fr/ark:/12148/bpt6k3244415
#   D=0.6511 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Lettre du bon genie de la Ville de Paris à celuy de Compiegne, sur l'heureux Retour du Roy. https://gallica.bnf.fr/ark:/12148/bpt6k857021t
# ------------------------------
# 1652 A tous les habitans de la terre, l'heureux genie. Salut . Les advenuës du bien souverain de l'homme. C'est à sc̜avoir; le traitté de la paix entre les hommes. De la guerre contre les vices : et de l'intelligence dans l'amour du ciel. Vray miroir de l'homme d'honneur, de l'homme sage, & de l'homme heureux https://gallica.bnf.fr/ark:/12148/bpt6k56542883
#   D=0.645 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1650 Lettre particuliere de cachet envoyée par la Reyne regente à Messieurs du Parlement. Ensemble une response à plusieurs choses, couchées en la Lettre envoyée au Mareschal de Turennes, & aux avis donnez aux Flamans. https://gallica.bnf.fr/ark:/12148/btv1b8606939c
# ------------------------------
# 1649 Visions astrologiques de Michel Nostradamus sur toutes les affaires de ce temps, et la confusion de Mazarin . En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k118539m
# ------------------------------
# 1650 Affectionnés+ souhaits du peuple de Paris, pour la conservation :&: +et+ progrés de leurs :Majestez: +Majestés+ dans leurs voyages, & leur marche en Bourgongne https://gallica.bnf.fr/ark:/12148/bpt6k55750332
# ------------------------------
# 1652 La nouvelle mazarinade, ou Le bruit qui court, de Mazarin. En Vers Burlesques. https://gallica.bnf.fr/ark:/12148/bpt6k56103334
# ------------------------------
# 1649 La Déroute des partisans rôtis. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5691659x
# ------------------------------
# 1652 L'echo du temps, touchant les divers changements de la fortune de Mazarin. https://gallica.bnf.fr/ark:/12148/bpt6k57079281
# ------------------------------
# 1652 Le tombeau et l'épitaphe de Mancini fils et neveu du Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k5720629s
# ------------------------------
# 1652 (Procuration donnée, le 1er octobre 1652, par Emmanuel-Joseph de Vignerod du Pont, comte de Richelieu, à Jacques Collet, pour régir à sa place ses deux abbayes de Saint-Ouen de Rouen, de Marmoutier-lez-Tours, et le prieuré de Saint-Martin-des-Champs.) https://gallica.bnf.fr/ark:/12148/bpt6k3224106
# ------------------------------
# 1652 Nouveau recueil général contenant toutes les chansons Mazarinistes et plusieurs qui n'ont point estées chantées, depuis la sorties de Messieurs les Princes, avec les tricotets et [...] de Mazarin, depuis sa sortie https://gallica.bnf.fr/ark:/12148/bpt6k5721652b
# ------------------------------
# 1649 La nouvelle courante à la Reine https://gallica.bnf.fr/ark:/12148/bpt6k56199901
# ------------------------------
# 1652 Les Oeufs rouge ["sic"] à Mazarin, apresté par M. Scaron en vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5612355b
# ------------------------------
# 1650 Déclaration de Jean de Labadie, cy-devant prestre, prédicateur et chanoine d'Amiens , contenant les raisons qui l'ont obligé à quitter la communion de l'Église romaine pour se ranger à celle de l'Église réformée... https://gallica.bnf.fr/ark:/12148/bpt6k76138t
# ------------------------------
# 1649 L'interprète des escrits du temps tant en proses qu'en rimes, et son sentiment burlesque sur iceux https://gallica.bnf.fr/ark:/12148/bpt6k5851766s
# ------------------------------
# 1649 Le nocturne enlevement du Roy hors de Paris, fait par le cardinal Mazarin la nuict des Roys. En vers burlesques. https://gallica.bnf.fr/ark:/12148/bpt6k1048495m
#   D=0.657 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Les ténèbres de Mazarin en vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5722005x
# ------------------------------
# 1649 Vers sur l'effigie ou image de la Justice qui estoit au haut du feu d'artifice fait en la place de Grève le 5 septembre 1649, en présence du Roy, le cardinal Mazarin estant près de Sa Majesté https://gallica.bnf.fr/ark:/12148/bpt6k5427554z
#   D=0.7099 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1652 Nouveau caquet ou entretien de l'accouchée, sur le départ du cardinal Mazarin de la ville de Dinan, jusques à son arrivée à Sedan. Première journée https://gallica.bnf.fr/ark:/12148/bpt6k8584110
#   D=0.7074 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1652 La discussion des quatre controverses politiques. I. Si la Puissance des Roys est de droict Divin, & si elle est absoluë. II. Si les Roys sont par dessus les Loix. III. Si les peuples ou Estats Generaux ont pouvoir de regler leur Puissance. IV. Si dans l'estat ou se trouvent maintenant les affaires, on peut faire un Regent ou Lieutenant pour le Roy. https://gallica.bnf.fr/ark:/12148/bpt6k80084g
#   D=0.6359 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Satyre sur les troubles de Paris, en vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5705773j
# ------------------------------
# 1651 Disputatio de finito et infinito in qua defenditur sententia clarissimi Cartesii de motu, spatio et corpore https://gallica.bnf.fr/ark:/12148/bpt6k96126571
# ------------------------------
# 1649 A Mazarin , sonnet https://gallica.bnf.fr/ark:/12148/bpt6k5657474p
# ------------------------------
# 1649 Recueil de quelques pièces contre le Cardinal Mazarin Au Cardinal Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k5426104c
# ------------------------------
# 1649 Le salve, Regina de Mazarin et des partisans https://gallica.bnf.fr/ark:/12148/bpt6k57081119
# ------------------------------
# 1654 Les Triomphes de Parthenie dédiés a Monseigneur, Monseigneur Guy de Bar, conseiller du roy en ses conseils, lieutenant general de ses armées, gouverneur de la ville & citadelle, & bailly d'Amiens. Par les escoliers du College de la Compagnie de Jesus, le 17. janvier 1654. une heure aprez midy https://gallica.bnf.fr/ark:/12148/bpt6k15250118
# ------------------------------
# 1649 Déclaration du roy, portant attribution de juger souverainement, & en dernier ressort de toutes causes, tant civiles que criminelles, à tous les présidiaux du ressort du Parlement de Paris . Et lesquelles ont esté luës, publiées et registrées, le jeudy vingt-huictieme janvier, l'audiance se tenant à Lyon https://gallica.bnf.fr/ark:/12148/bpt6k9674804v
# ------------------------------
# 1651 Lettre de Monsieur le prince escrite a Messieurs du Parlement ; sur le sujet de l'écrit de la reyne, porté par Messieurs les gens du roy https://gallica.bnf.fr/ark:/12148/btv1b86263371
#   D=0.685 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Le Satyrique ou Le Mazarin metamorphosé. Première partie https://gallica.bnf.fr/ark:/12148/bpt6k5707904m
# ------------------------------
# 1649 A un ministre d' Estat, sur les œufs. https://gallica.bnf.fr/ark:/12148/bpt6k56575014
#   D=0.9048 (ID=13): A un ministre d’État sur les œufs
#
# ------------------------------
# 1649 Les rudimens ou commencemens de la grammaire latine. Les déclinaisons des noms, des pronoms, des verbes, et de leurs participes / , divisez en deux parties... https://gallica.bnf.fr/ark:/12148/bpt6k30429361
# ------------------------------
# 1649 Véritable censure de la "Lettre d'avis, écrite par un provincial à MM. du parlement" ; et la véritable censure de la "Réponse" à la même lettre, avec la réfutation de la "Réplique" à ladite réponse... par un des plus illustres grammairiens de Samothrace https://gallica.bnf.fr/ark:/12148/bpt6k8410242
#   D=0.667 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1654 Arrêt notable rendu au parlement de Paris qui confirme les privilèges accordés par le Roi pour les dessèchements des marais https://gallica.bnf.fr/ark:/12148/btv1b8620837w
# ------------------------------
# 1649 Seconde partie du Satyre ou Le Mazarin métamorphosé. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5707793x
# ------------------------------
# 1650 Musurgia universalis sive Ars magna consoni et dissoni. Tomus II. T2 https://gallica.bnf.fr/ark:/12148/bpt6k123681g
# ------------------------------
# 1648 Nouvelles oeuvres de feu Mr Théophile , composées d'excellentes lettres françoises et latines, soigneusement recueillies, mises en ordre et corrigées par Mr Mayret https://gallica.bnf.fr/ark:/12148/bpt6k717566
# ------------------------------
# 1649 A Monsieur de Broussel conseiller du Roy au parlement de Paris https://gallica.bnf.fr/ark:/12148/bpt6k5660368q
#   D=0.8506 (ID=5): À monsieur de Broussel , conseiller du roi au parlement de Paris
#
# ------------------------------
# 1649 Hircanus tragoedia dabitur in Theatrum Regiae Navarrae ad solennem praemiorum distributionem ex munificentia Ludovici XIIII regis christianissimi die lunae 30. Augusti M.DC.XLIX. post meridiem https://gallica.bnf.fr/ark:/12148/bpt6k1523873h
# ------------------------------
# 1651 La desroute des Mazarins par les frondeurs https://gallica.bnf.fr/ark:/12148/bpt6k5696362x
# ------------------------------
# 1654 Regis christianissimi Ludovici Adeodati felix inauguratio anno 1654 jun. 7. (Auctore Christophoro Dehennotio.) https://gallica.bnf.fr/ark:/12148/bpt6k327395x
# ------------------------------
# 1649 Le voeu des Parisiens à la Vierge, pour le retour de leurs Majestez dans leur bonne ville de Paris. https://gallica.bnf.fr/ark:/12148/bpt6k5426118d
# ------------------------------
# 1651 Le Paranimphe Mazarinique https://gallica.bnf.fr/ark:/12148/bpt6k5612227p
# ------------------------------
# 1648 De Byzantinæ historiæ scriptoribus , sub felicissimis Ludovici XIV. Francorum ac Navarræorum regis christianissimi auspiciis publicam in lucem e luparæa typographia emittendis. Ad omnes per Europam eruditos. ΠΡΟΤΡΕΠΤΙΚΟΝ. https://gallica.bnf.fr/ark:/12148/bpt6k1159077
# ------------------------------
# 1650 L'Accueil faict a Son Eminence par les Bordelois https://gallica.bnf.fr/ark:/12148/bpt6k5660410v
# ------------------------------
# 1652 Les presens faits à Son A. royalle et à Messieurs les Princes de Condé et de Beaufort à leur arrivée au Palais. Pour Messieurs du Parlement https://gallica.bnf.fr/ark:/12148/bpt6k57085353
# ------------------------------
# 1649 L'ambassadeur des estats de Catalogne... à la Reine régente mère du Roy... : à la Reine Régente Mère du Roy, touchant les affaires de cette province, et la paix particulière et générale / envoyé par Don Ioseph de Marguerite,... https://gallica.bnf.fr/ark:/12148/bpt6k629872
#   D=0.6559 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1652 Triolets sur la mode de la paille qui court https://gallica.bnf.fr/ark:/12148/bpt6k5429379q
# ------------------------------
# 1649 Les remerciemens de la France, Pour la Paix. A Monseigneur le prince de Conty. https://gallica.bnf.fr/ark:/12148/bpt6k5675934t
# ------------------------------
# 1650 Journal des délibérations tenues en Parlement, toutes les Chambres assemblées, & à l'Hostel d'Orleans depuis le 5. jour d'Aoust 1650. jusques à présent, ou ont assisté Monseigneur le Duc d'Orleans, Messieurs de Beaufort, de l'hospital, de Brissac, & le Coadjuteur : Touchant l'éloignement du Cardinal Mazarin, la Guerre de Bourdeaux, & l'affaire de Messieurs les Princes : Avec les Harangues faites sur ce sujet par Messieurs les Presidents & Conseillers, & les Arrests donnez en consequence https://gallica.bnf.fr/ark:/12148/btv1b8606944p
#   D=0.591 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1652 Relation burlesque véritable de tout ce qui s'est passé dans la Fronde de Paris jusques à présent, envoyée au cardinal Mazarin par un provincial [Scarron], ou Histoire burlesque du ministère et des disgrâces du cardinal Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k5427529w
#   D=0.6767 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1650 La Réjouissance des poètes à Mgr le Duc d'Orléans sur l'heureuse naissance de Mgr le Prince son fils, par le sieur Colletet, le fils https://gallica.bnf.fr/ark:/12148/bpt6k5661757m
#   D=0.6902 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Le parlement de Bourgogne, son origine, son établissement et son progrès , avec les noms, sur-noms, qualités, armes et blasons, des présidents, chevaliers, conseillers, avocats et procureurs généraux, et greffiers, qui y ont été jusques à présent, par Pierre Palliot,... https://gallica.bnf.fr/ark:/12148/bpt6k94759c
#   D=0.6405 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 L'achat de Mazarin, en vers burlesques. https://gallica.bnf.fr/ark:/12148/bpt6k55769500
# ------------------------------
# 1651 Lettre de la signora Foutakina à messer Julio Mazarini, touchant l'armement des bardaches pour donner secours à son Éminence, en vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k8570137
# ------------------------------
# 1648 Le Virgile travesty en vers burlesques , de M. Scarron. Dédié à la Reyne https://gallica.bnf.fr/ark:/12148/bpt6k123053b
# ------------------------------
# 1648 L'agreable entretien des ames sur .168. tableaux souscris de prieres . Pour mediter les Sts. mistères. Et pour régler nos vies et moeurs, sur celles de notre sauveur Jesus Christ et de Ste. Marie sa mere, en disant le chapelet du rozaire https://gallica.bnf.fr/ark:/12148/bpt6k15207025
#   D=0.6709 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1651 L'entretien du cardinal Mazarin avec ses niepces https://gallica.bnf.fr/ark:/12148/bpt6k57027459
# ------------------------------
# 1649 Humble requeste de Son Eminence addressée à Messieurs du Parlement. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5851801s
# ------------------------------
# 1654 Catalogue des chevaliers de l'Ordre du Collier de Savoie, dit de l'Annonciade, avec leurs noms, surnoms, qualités, armes et blasons, depuis son institution par Amé VI... en l'an 1362, jusques à S. A. R. Charles-Emmanuel II... justifié par les anciens et nouveaux statuts et registres de l'ordre... par François Capré,... https://gallica.bnf.fr/ark:/12148/bpt6k15202404
#   D=0.6447 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1648 Relation de ce qui s'est passé de plus remarquable ès missions des Pères de la Compagnie de Jésus en la Nouvelle France en l'année 1647 envoyée au R. P. provincial de la province de France, par le supérieur des missions de la mesme compagnie. [Signé : Hiérosme Lalament.]. Relation de ce qui s'est passé de plus remarquable en la mision des Pères de la Compagnie de Jésus aux Hurons, païs de la Nouvelle France... [Signé : Paul Raguenau] https://gallica.bnf.fr/ark:/12148/bpt6k8705167c
# ------------------------------
# 1649 Historiae Francorum scriptores coaetanei,... quorum plurimi nunc primum ex variis codicibus mss. in lucem prodeunt, alii verò auctiores et emendatiores ; cum epistolis regum, reginarum, pontificum, ducum,... et aliis veteribus rerum francicarum monumentis ; opera ac studio Andreae Du Chesne,... https://gallica.bnf.fr/ark:/12148/bpt6k65844393
# ------------------------------
# 1653 Memoire en l'affaire des religieux de S. Antoine de Reims. Contre les lieutenant & gents du conseil de ladite ville https://gallica.bnf.fr/ark:/12148/bpt6k3045572f
# ------------------------------
# 1648 Typhon, ou La gigantomachie . Poëme burlesque. Dedie a monseigneur l'eminentissime cardinal Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k72451w
# ------------------------------
# 1649 Plaidoyé heroy-comique pour l'eminence contre le creux https://gallica.bnf.fr/ark:/12148/bpt6k57247249
# ------------------------------
# 1651 Le banissement de Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k5576645n
# ------------------------------
# 1649 Triolets sur Cambray https://gallica.bnf.fr/ark:/12148/bpt6k54293648
# ------------------------------
# 1652 L'agreable conferance de deux Normans, s'estans rencontrez sur le Pont-Neuf de cette ville de Paris, traitans sur les affaires du temps present . Dont l'un se nomme Perrin, & l'autre Colas. Dialogue. https://gallica.bnf.fr/ark:/12148/bpt6k1335801
# ------------------------------
# 1651 Lettre escrite de Bazas par un Ecclésiastique a un Prestre de Sainct Sulpice,... contenante l'Apostasie d'un Ianséniste nommé Labadie, lequel a renoncé à l'Eglise Romaine. Et a protesté en se faisant qu'il n'a pas changé la croyance du Iansénisme en professant le Calvinisme,... https://gallica.bnf.fr/ark:/12148/bpt6k855244q
# ------------------------------
# 1649 Paraphrase sur le bref de sa saincteté envoyé à la Reyne régente mère du Roy, touchant sa reconciliation avec plusieurs des plus signalez de son royaume et le soulagement de son peuple. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k56122676
#   D=0.6923 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Diverses pieces sur les colomnes et pilliers des maltotiers Et les vingt Rimes sur leur Patriarche. https://gallica.bnf.fr/ark:/12148/bpt6k56955718
# ------------------------------
# 1648 La suite des oeuvres burlesques de Mr Scaron . Seconde partie https://gallica.bnf.fr/ark:/12148/bpt6k72447n
# ------------------------------
# 1652 La France desolee parlant au Roy estant à la chasse , où elle luy represente la fin tragique du marquis d'Ancre, & la vie du cardinal Mazarin : avec le moyen de mettre la France en paix. Dediee a monsieur le prince de Condé https://gallica.bnf.fr/ark:/12148/bpt6k855547s
# ------------------------------
# 1649 Remonstrance burlesque, au Parlement. https://gallica.bnf.fr/ark:/12148/bpt6k5426081t
# ------------------------------
# 1648 L'humble remonstrance des bons François à Nosseigneurs de Parlement https://gallica.bnf.fr/ark:/12148/bpt6k58517713
# ------------------------------
# 1648 Dom Bernard de Cabrère, tragi-comédie de Rotrou [avec une "Élégie" de l'auteur à Mazarin] https://gallica.bnf.fr/ark:/12148/btv1b86221195
# ------------------------------
# 1650 Lettre de Messieurs du Parlement de Bourdeaux, presentée le samedy 6. aoust 1650. A Messieurs du Parlement de Paris ; Par messieurs les Deputez dudit Parlement de Bourdeaux : sur le sujet de la continuation des violences du sieur duc d'Espernon, protégé par Monsieur le cardinal Mazarin. https://gallica.bnf.fr/ark:/12148/bpt6k375125j
#   D=0.6179 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1652 Les estrennes burlesques de M. Scaron envoyées à Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k57008933
# ------------------------------
# 1648 Traité des merveilles operees en la chapelle Notre Dame du Calvaire de Beth-Aram ... Composé par P. de Marca conseiller ordinaire du Roy en ses conseils... Seconde edition. Reveuë & augmentée de plusieurs miracles par les prêtres de la congregation de ce lieu. https://gallica.bnf.fr/ark:/12148/bpt6k315671v
#   D=0.6567 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1651 Le cardinal errant https://gallica.bnf.fr/ark:/12148/bpt6k5676049g
# ------------------------------
# 1651 Lettre de remerciment envoyee au cardinal Mazarin sur la lettre qu'il a escrite à une dame de la cour pour l'accommodement de ses affaires . Avec la harangue de Dame Denise au large chaperon des Halles, deputée vers son everminence par la Communauté de toutes les beurrieres, de la ville, cité & université de Paris, touchant les bien faits qu'elle a receu d'elle pendant tout le caresme dernier https://gallica.bnf.fr/ark:/12148/bpt6k857089x
#   D=0.6158 (ID=19): Accouchée (l') espagnole, avec le caquet des politiques, ou le frère e
# ------------------------------
# 1649 Le crève-coeur, et les sanglots de Monsieur le Prince. Addressez à la France. https://gallica.bnf.fr/ark:/12148/bpt6k5708437k
# ------------------------------
# 1650 Les origines de la langue françoise https://gallica.bnf.fr/ark:/12148/bpt6k1228614
# ------------------------------
# 1649 Raillerie universelle, dediee aux curieux de ce temps . En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5429547f
# ------------------------------
# 1649 L'Adieu de Jules Mazarin à la France, à Paris, et à Messieurs du Parlement. (Signé : Francese Cornelio.) https://gallica.bnf.fr/ark:/12148/bpt6k5707805p
# ------------------------------
# 1652 La Bouteille cassee, attachee avec une Fronde au cul de Mazarin, fuyant apres avoir sceu la grande deffaite de son armée, par celle de son Altesse Royale, commandée par Monseigneur le Prince de Condé. Satyre divertissante. https://gallica.bnf.fr/ark:/12148/bpt6k5660977r
# ------------------------------
# 1649 Stances au Roy. Et à Messieurs de Parlement. https://gallica.bnf.fr/ark:/12148/bpt6k5576444j
# ------------------------------
# 1652 La vérité du temps reconnuë de tous https://gallica.bnf.fr/ark:/12148/bpt6k5425940p
# ------------------------------
# 1651 Le récit du grand combat donné entre deux dames de la ville de Cologne et les deux niéces du Cardinal Mazarin. Sur les affaires du temps présent https://gallica.bnf.fr/ark:/12148/bpt6k5426107m
# ------------------------------
# 1652 L'Icare Sicilien, ou La cheute [sic] de Mazarin, avec sa Metamorphose, en vers burlesques : Où le Lecteur reconnoistra l'obligation que nous avons au defunct Cardinal de Richelieu, de nous avoir procuré un si bon Ministre. https://gallica.bnf.fr/ark:/12148/bpt6k5849239c
# ------------------------------
# 1653 Psalmen und geistliche Lieder D. M Lutheri, unnd anderer frommen Christen https://gallica.bnf.fr/ark:/12148/bpt6k91171478
# ------------------------------
# 1652 Le stratagesme ou Le Pour et contre du départ de Mazarin. En vers burlesques https://gallica.bnf.fr/ark:/12148/bpt6k5610320h
# ------------------------------
# 1649 Vers satyriques sur les noms et vies des Partisans etc. https://gallica.bnf.fr/ark:/12148/bpt6k5427555c
# ------------------------------
# 1649 Satyre de Mazarin, envoyé à Monsieur le Duc de Beaufort. https://gallica.bnf.fr/ark:/12148/bpt6k5699286x
# ------------------------------
# 1650 Lettre de Madame la Princesse Doüairière de Condé, presentée à la Reine Regente. Contenant tous les moyens dont le Cardinal Mazarin s'est servy pour empescher la Paix, pour ruiner le Parlement & le Peuple de Paris ; pour tâcher de perdre Monsieur le Duc de Beaufort, Monsieur le Coadjuteur, Monsieur de Brousselles, & Monsieur le President Charton ; par l'assassinat supposé contre la personne de Monsieur le Prince ; & pour emprisonner Messieurs les Princes de Condé & de Conty, & Monsieur le Duc de Longueville. https://gallica.bnf.fr/ark:/12148/bpt6k1321103
# ------------------------------
# 1649 Le Panégyrique du cardinal Mazarini, par L. A. P. https://gallica.bnf.fr/ark:/12148/bpt6k5791851j
# ------------------------------
# 1649 Rondeau du Roy contre le cardinal Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k5426071f
# ------------------------------
# 1652 Discours ou entretien d'un bourgeois de Paris avec un gentilhomme Mazarin https://gallica.bnf.fr/ark:/12148/bpt6k1352981

# %% [markdown]
# **L'ensemble des résultats de l'application se trouvent dans le dossier de sortie "output".**
